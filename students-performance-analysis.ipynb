# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/student-performance-analysis/StudentsPerformance.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sp=pd.read_csv('/kaggle/input/student-performance-analysis/StudentsPerformance.csv')
sp.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sp.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sp['gender'].value_counts().plot.bar(
    title = 'Frequency Distribution of Gender',
    color = ['#1f78b4', '#33a02c'],
    figsize = (4,3)
)
# Out:
# <Axes: title={'center': 'Frequency Distribution of Gender'}, xlabel='gender'>

# %%
sp['race/ethnicity'].value_counts().plot.barh(
    title ='Frequency Distribution of Race/Ethnicity',
    color = ['#1f78b4', '#33a02c', '#e41a1c', '#377eb8', '#984ea3'],
    figsize = (6, 4)
)

plt.show()

# %%
sp['parental level of education'].value_counts().plot.bar(
    title ='Frequency Distribution of Parental Level of Education',
    color = ['#1f78b4', '#33a02c', '#e41a1c', '#377eb8', '#984ea3', '#ff7f00'],
    figsize = (6,4)
)
# Out:
# <Axes: title={'center': 'Frequency Distribution of Parental Level of Education'}, xlabel='parental level of education'>

# %%
sp['lunch'].value_counts().plot.bar(
    title = 'Frequency Distribution of Lunch',
    color=['#1f78b4', '#33a02c'],
    figsize = (4,3)
)
# Out:
# <Axes: title={'center': 'Frequency Distribution of Lunch'}, xlabel='lunch'>

# %%
sp['test preparation course'].value_counts().plot.bar(
    title = 'Frequency Distribution of Test Preparation Course',
    color=['#1f78b4', '#33a02c'],
    figsize=(4,3)
)
# Out:
# <Axes: title={'center': 'Frequency Distribution of Test Preparation Course'}, xlabel='test preparation course'>

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = sp['gender'].value_counts()
labels = 'Female', 'Male'
color = ['#1f78b4', '#33a02c']

plt.pie(size, colors = color, labels = labels,autopct='%2.2f%%', textprops={'fontsize': 16})
plt.title('Gender', fontsize = 22)
plt.axis('off')


plt.subplot(1, 5, 2)
size = sp['race/ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['#1f78b4', '#33a02c', '#e41a1c', '#377eb8', '#984ea3'] 

plt.pie(size, colors = color,labels = labels,autopct='%2.2f%%', textprops={'fontsize': 16})
plt.title('Race/Ethnicity', fontsize = 22)
plt.axis('off')


plt.subplot(1, 5, 3)
size = sp['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['#1f78b4', '#33a02c']

plt.pie(size, colors = color,labels = labels,autopct='%2.2f%%', textprops={'fontsize': 16})
plt.title('Lunch', fontsize = 22)
plt.axis('off')


plt.subplot(1, 5, 4)
size = sp['test preparation course'].value_counts()
labels = 'None', 'Completed'
color = ['#1f78b4', '#33a02c']

plt.pie(size, colors = color,labels = labels,autopct='%2.2f%%', textprops={'fontsize': 16})
plt.title('Test Course', fontsize = 22)
plt.axis('off')


plt.subplot(1, 5, 5)
size = sp['parental level of education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['#1f78b4', '#33a02c', '#e41a1c', '#377eb8', '#984ea3', '#ff7f00'] 

plt.pie(size, colors = color,labels = labels,autopct='%2.2f%%', textprops={'fontsize': 16})
plt.title('Parental Education', fontsize = 22)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %% [markdown]
# 1. The gender distribution among students is nearly balanced, with a roughly equal number of male and female students.
# 2. Group C exhibits the highest student population among the various groups.
# 3. A larger proportion of students opt for standard lunch as opposed to other meal options.
# 4. A significant number of students have not enrolled in any test preparation courses.
# 5. The predominant level of parental education among students is "Some College," with "Associate's Degree" following closely as the second-highest educational attainment level.

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.barplot(x=sp['math score'].value_counts().index, y=sp['math score'].value_counts(), palette='bright')
plt.title('Math Score Comparison', fontsize=20)
plt.xlabel('Math Score', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ****Maximum number of students had a Maths Score of 65****

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.barplot(x=sp['reading score'].value_counts().index, y=sp['reading score'].value_counts(), palette='bright')
plt.title('Reading Score Comparison', fontsize=20)
plt.xlabel('Reading Score', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Maximum number of students had a Reading Score of 71**

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.barplot(x=sp['writing score'].value_counts().index, y=sp['writing score'].value_counts(), palette='bright')
plt.title('Writing Score Comparison', fontsize=20)
plt.xlabel('Writing Score', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Maximum number of students had a Writing Score of 74**

# %%
colors = ['skyblue', 'lightgreen', 'lightcoral']

fig, axes = plt.subplots(1, 3, figsize=(20, 6), sharey=True)

sns.violinplot(y='math score', data=sp, color=colors[0], linewidth=2, ax=axes[0])
axes[0].set_title('Math Scores', fontsize=16)
axes[0].set_xlabel('Math Score', fontsize=14)
axes[0].set_ylabel('Distribution', fontsize=14)

sns.violinplot(y='reading score', data=sp, color=colors[1], linewidth=2, ax=axes[1])
axes[1].set_title('Reading Scores', fontsize=16)
axes[1].set_xlabel('Reading Score', fontsize=14)
axes[1].set_ylabel('')  # No y-axis label for better layout

sns.violinplot(y='writing score', data=sp, color=colors[2], linewidth=2, ax=axes[2])
axes[2].set_title('Writing Scores', fontsize=16)
axes[2].set_xlabel('Writing Score', fontsize=14)
axes[2].set_ylabel('')  # No y-axis label for better layout

plt.tight_layout()
plt.show()

# %% [markdown]
# **Maximum number of students have scored between 60-80 marks in all 3 subjects**

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="gender", y="math score", data=sp)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x="gender", y="reading score", data=sp)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x="gender", y="writing score", data=sp)
plt.show()

# %% [markdown]
# **Male students scored higher in Maths whereas Female students scored higher in Reading and Writing**

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender", y="math score", x="test preparation course", data=sp)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender", y="reading score", x="test preparation course", data=sp)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender", y="writing score", x="test preparation course", data=sp)
plt.show()

# %% [markdown]
# **Students who completed the test preparation course acheived higher scored in all 3 subject**

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender", y="math score", x="lunch", data=sp)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender", y="reading score", x="lunch", data=sp)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender", y="writing score", x="lunch", data=sp)
plt.show()

# %% [markdown]
# **Students who chose standard lunch acheived higher scored in all 3 subject**

# %%
passingmark=40
sp['pass_math'] = np.where(sp['math score']>= passingmark, 'Pass', 'Fail')
sp['pass_math'].value_counts(dropna = False).plot.bar(color=['green','red'], figsize = (3,3))

plt.title('Comparison between Pass/Fail in Maths')
plt.xlabel('Result')
plt.ylabel('Count')
plt.show()
sp['pass_math'].value_counts()
# Out:
# pass_math
# Pass    960
# Fail     40
# Name: count, dtype: int64

# %%
sp['pass_read'] = np.where(sp['reading score']>= passingmark, 'Pass', 'Fail')
sp['pass_read'].value_counts(dropna = False).plot.bar(color = ['green','red'], figsize = (3,3))
plt.title('Comparison between Pass/Fail in Reading')
plt.xlabel('Result')
plt.ylabel('Count')
plt.show()
sp['pass_read'].value_counts()
# Out:
# pass_read
# Pass    974
# Fail     26
# Name: count, dtype: int64

# %%
sp['pass_write'] = np.where(sp['writing score']>= passingmark, 'Pass', 'Fail')
sp['pass_write'].value_counts(dropna = False).plot.bar(color = ['green','red'], figsize = (3,3))
plt.title('Comparison between Pass/Fail in Writing')
plt.xlabel('Result')
plt.ylabel('Count')
plt.show()
sp['pass_write'].value_counts()
# Out:
# pass_write
# Pass    968
# Fail     32
# Name: count, dtype: int64

# %%
sp['total_score'] = sp['math score'] + sp['reading score'] + sp['writing score']

sp['total_score'].value_counts(normalize = True)
sp['total_score'].value_counts(dropna = True).plot.bar(color = 'green', figsize = (40,10))

plt.title('Comparison Of Total Score Of All Students')
plt.xlabel('Total Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Maximum number of students had a Total Score of 204**

# %%
from math import *

sp['percentage'] = sp['total_score'] / 3

for i in range(1000):
    sp.loc[i, 'percentage'] = ceil(sp.loc[i, 'percentage'])

percentage_counts = sp['percentage'].value_counts(normalize=True)
percentage_counts.plot.bar(figsize=(20, 8), color='green')

plt.title('Comparison Of Percentage Of All The Students')
plt.xlabel('Percentage')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Maximum number of students scored 69 Percent**

# %%
sp['result'] = sp.apply(lambda x : 'Fail' if x['pass_math'] == 'Fail' or 
                           x['pass_read'] == 'Fail' or x['pass_write'] == 'Fail'
                           else 'Pass', axis = 1)

sp['result'].value_counts(dropna = False).plot.bar(color = ['green','red'], figsize = (3, 3))
plt.title('Overall Result')
plt.xlabel('Result')
plt.ylabel('Count')
plt.show()

sp['result'].value_counts()
# Out:
# result
# Pass    949
# Fail     51
# Name: count, dtype: int64

# %%
def calcgrade(percentage, result):
    if result == 'Fail':
        return 'E'
    if(percentage >= 85):
        return 'A'
    if(percentage >= 75):
        return 'B'
    if(percentage >= 50):
        return 'C'
    if(percentage >=33):
        return 'D'
    else:
        return 'E'
    
sp['grade']= sp.apply(lambda x: calcgrade(x['percentage'], x['result']), axis = 1 )

sp['grade'].value_counts().plot.bar(title='Frequency Distribution of Grades',color= ['#1f78b4', '#33a02c', '#e41a1c', '#377eb8', '#984ea3'],figsize=(10,8))
# Out:
# <Axes: title={'center': 'Frequency Distribution of Grades'}, xlabel='grade'>

# %% [markdown]
# **Maximum number of students received Grade C**

# %%
sns.pairplot(sp,hue = 'gender')
plt.show()

# %%
sns.countplot(x = sp['grade'], data=sp, hue = sp['gender'])
plt.show()

# %% [markdown]
# **Maximum number of students that acheived Grade A and Grade B were Females**

# %%
sns.countplot(x = sp['race/ethnicity'], data=sp, hue = sp['grade'])
plt.show()

# %% [markdown]
# **Maximum number of students that acheived high grades like Grade A and Grade B were from Group C and Group D**

# %%
sns.countplot(x = sp['parental level of education'], data=sp, hue = sp['grade'])
plt.show()

# %% [markdown]
# **Number of students whose parents had an associate's degree scored higher than other students**

# %%
sns.countplot(x = sp['grade'], data=sp, hue = sp['lunch'])
plt.show()

# %% [markdown]
# **Number of students who chose standard lunch scored higher than other student**

# %%
sns.countplot(x = sp['grade'], data=sp, hue = sp['test preparation course'])
plt.show()

# %% [markdown]
# **Number of students that completed the test preparation course and got Grade A were higher**

# %%
numeric_columns = sp.select_dtypes(include=['float64', 'int64']).columns
sp_corr = sp[numeric_columns].corr()

plt.figure(figsize=(20, 10))
sns.set(font_scale=1.2)
ax = sns.heatmap(sp_corr, annot=True, cmap="Greens")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)

plt.show()
